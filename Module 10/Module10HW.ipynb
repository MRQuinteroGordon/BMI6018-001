# %% [markdown]
# # Assignment: Melt, Pivot, Aggregations and Iteration
# ### Completed by Michelle Gordon using Breast Cancer dataset

# %% [markdown]
# In this assignment you will experiment on your own. Using a health dataset of your choice (check with us if you are not sure), write code to demonstrate the following Pandas functions:
#
# * Melt -DONE
# * Pivot -DONE
# * Aggregation -DONE
# * Iteration -DONE
# * Groupby -DONE
#
# Each function demonstration will be for 30 points for a total of 150 points. Ensure that you include comments within your code and follow the rubric as a guide. Submit using your GitHub site. Ask if you have any questions.

# %%
import pandas as pd

df = pd.read_csv("breast-cancer.data", header=None)
df.columns = ['recurrence_class', 'age', 'menopause', 'tumor-size', 'inv_nodes', 'node-caps', 'deg-malig', 'breast', 'breast-quad', 'irradiat']
df.head()
# Out:
#        recurrence_class    age menopause tumor-size inv_nodes node-caps  \
# 0  no-recurrence-events  30-39   premeno      30-34       0-2        no
# 1  no-recurrence-events  40-49   premeno      20-24       0-2        no
# 2  no-recurrence-events  40-49   premeno      20-24       0-2        no
# 3  no-recurrence-events  60-69      ge40      15-19       0-2        no
# 4  no-recurrence-events  40-49   premeno        0-4       0-2        no
#
#    deg-malig breast breast-quad irradiat
# 0          3   left    left_low       no
# 1          2  right    right_up       no
# 2          2   left    left_low       no
# 3          2  right     left_up       no
# 4          2  right   right_low       no

# %% [markdown]
# ### Aggregation
# What is the range of ages in the dataframe, and what is the average degree of malignancy of all the cases?

# %%
# what are the min and max ages and degree of malignancy, and what is the average degree of malignancy?
df.agg({'age': ['min', 'max'], 'deg-malig' : ['min', 'max', 'mean']})
# Out:
#         age  deg-malig
# min   20-29   1.000000
# max   70-79   3.000000
# mean    NaN   2.048951

# %% [markdown]
# ### Group By
# I want to see what breast regions have the highest number of cases

# %%
# count number of cases in dataset grouped by which breast, and location on breast
cases_by_location = pd.DataFrame(df.groupby(['breast', 'breast-quad'], as_index = False)['age'].count())
# giving columns more readable names
cases_by_location.columns = ['breast', 'breast_quadrant', '# of cases']
# sort to show highest values at the top
cases_by_location.sort_values('# of cases', ascending=False)
# Out:
#    breast breast_quadrant  # of cases
# 2    left        left_low          78
# 8   right         left_up          61
# 3    left         left_up          36
# 7   right        left_low          32
# 10  right        right_up          24
# 4    left       right_low          17
# 1    left         central          11
# 6   right         central          10
# 5    left        right_up           9
# 9   right       right_low           7
# 0    left               ?           1

# %% [markdown]
# It looks like the left_low quadrant of the left breast and the left_up quadrant of the right breast have the most cases
#
# ### Iteration
# I want to see each individual record

# %%
for index, row in df.iterrows():
    print(f"Index#: {index}\nValues:\n{row}\n")
    # print("\n")
    # print(index,row)
# Out:
# Index#: 0
# Values:
# recurrence_class    no-recurrence-events
# age                                30-39
# menopause                        premeno
# tumor-size                         30-34
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              3
# breast                              left
# breast-quad                     left_low
# irradiat                              no
# Name: 0, dtype: object
#
# Index#: 1
# Values:
# recurrence_class    no-recurrence-events
# age                                40-49
# menopause                        premeno
# tumor-size                         20-24
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              2
# breast                             right
# breast-quad                     right_up
# irradiat                              no
# Name: 1, dtype: object
#
# Index#: 2
# Values:
# recurrence_class    no-recurrence-events
# age                                40-49
# menopause                        premeno
# tumor-size                         20-24
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              2
# breast                              left
# breast-quad                     left_low
# irradiat                              no
# Name: 2, dtype: object
#
# Index#: 3
# Values:
# recurrence_class    no-recurrence-events
# age                                60-69
# menopause                           ge40
# tumor-size                         15-19
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              2
# breast                             right
# breast-quad                      left_up
# irradiat                              no
# Name: 3, dtype: object
#
# Index#: 4
# Values:
# recurrence_class    no-recurrence-events
# age                                40-49
# menopause                        premeno
# tumor-size                           0-4
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              2
# breast                             right
# breast-quad                    right_low
# irradiat                              no
# Name: 4, dtype: object
#
# Index#: 5
# Values:
# recurrence_class    no-recurrence-events
# age                                60-69
# menopause                           ge40
# tumor-size                         15-19
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              2
# breast                              left
# breast-quad                     left_low
# irradiat                              no
# Name: 5, dtype: object
#
# Index#: 6
# Values:
# recurrence_class    no-recurrence-events
# age                                50-59
# menopause                        premeno
# tumor-size                         25-29
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              2
# breast                              left
# breast-quad                     left_low
# irradiat                              no
# Name: 6, dtype: object
#
# Index#: 7
# Values:
# recurrence_class    no-recurrence-events
# age                                60-69
# menopause                           ge40
# tumor-size                         20-24
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              1
# breast                              left
# breast-quad                     left_low
# irradiat                              no
# Name: 7, dtype: object
#
# Index#: 8
# Values:
# recurrence_class    no-recurrence-events
# age                                40-49
# menopause                        premeno
# tumor-size                         50-54
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              2
# breast                              left
# breast-quad                     left_low
# irradiat                              no
# Name: 8, dtype: object
#
# Index#: 9
# Values:
# recurrence_class    no-recurrence-events
# age                                40-49
# menopause                        premeno
# tumor-size                         20-24
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              2
# breast                             right
# breast-quad                      left_up
# irradiat                              no
# Name: 9, dtype: object
#
# Index#: 10
# Values:
# recurrence_class    no-recurrence-events
# age                                40-49
# menopause                        premeno
# tumor-size                           0-4
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              3
# breast                              left
# breast-quad                      central
# irradiat                              no
# Name: 10, dtype: object
#
# Index#: 11
# Values:
# recurrence_class    no-recurrence-events
# age                                50-59
# menopause                           ge40
# tumor-size                         25-29
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              2
# breast                              left
# breast-quad                     left_low
# irradiat                              no
# Name: 11, dtype: object
#
# Index#: 12
# Values:
# recurrence_class    no-recurrence-events
# age                                60-69
# menopause                           lt40
# tumor-size                         10-14
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              1
# breast                              left
# breast-quad                     right_up
# irradiat                              no
# Name: 12, dtype: object
#
# Index#: 13
# Values:
# recurrence_class    no-recurrence-events
# age                                50-59
# menopause                           ge40
# tumor-size                         25-29
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              3
# breast                              left
# breast-quad                     right_up
# irradiat                              no
# Name: 13, dtype: object
#
# Index#: 14
# Values:
# recurrence_class    no-recurrence-events
# age                                40-49
# menopause                        premeno
# tumor-size                         30-34
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              3
# breast                              left
# breast-quad                      left_up
# irradiat                              no
# Name: 14, dtype: object
#
# Index#: 15
# Values:
# recurrence_class    no-recurrence-events
# age                                60-69
# menopause                           lt40
# tumor-size                         30-34
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              1
# breast                              left
# breast-quad                     left_low
# irradiat                              no
# Name: 15, dtype: object
#
# Index#: 16
# Values:
# recurrence_class    no-recurrence-events
# age                                40-49
# menopause                        premeno
# tumor-size                         15-19
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              2
# breast                              left
# breast-quad                     left_low
# irradiat                              no
# Name: 16, dtype: object
#
# Index#: 17
# Values:
# recurrence_class    no-recurrence-events
# age                                50-59
# menopause                        premeno
# tumor-size                         30-34
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              3
# breast                              left
# breast-quad                     left_low
# irradiat                              no
# Name: 17, dtype: object
#
# Index#: 18
# Values:
# recurrence_class    no-recurrence-events
# age                                60-69
# menopause                           ge40
# tumor-size                         30-34
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              3
# breast                              left
# breast-quad                     left_low
# irradiat                              no
# Name: 18, dtype: object
#
# Index#: 19
# Values:
# recurrence_class    no-recurrence-events
# age                                50-59
# menopause                           ge40
# tumor-size                         30-34
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              1
# breast                             right
# breast-quad                     right_up
# irradiat                              no
# Name: 19, dtype: object
#
# Index#: 20
# Values:
# recurrence_class    no-recurrence-events
# age                                50-59
# menopause                           ge40
# tumor-size                         40-44
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              2
# breast                              left
# breast-quad                     left_low
# irradiat                              no
# Name: 20, dtype: object
#
# Index#: 21
# Values:
# recurrence_class    no-recurrence-events
# age                                60-69
# menopause                           ge40
# tumor-size                         15-19
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              2
# breast                              left
# breast-quad                     left_low
# irradiat                              no
# Name: 21, dtype: object
#
# Index#: 22
# Values:
# recurrence_class    no-recurrence-events
# age                                30-39
# menopause                        premeno
# tumor-size                         25-29
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              2
# breast                             right
# breast-quad                     left_low
# irradiat                              no
# Name: 22, dtype: object
#
# Index#: 23
# Values:
# recurrence_class    no-recurrence-events
# age                                50-59
# menopause                        premeno
# tumor-size                         40-44
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              2
# breast                              left
# breast-quad                      left_up
# irradiat                              no
# Name: 23, dtype: object
#
# Index#: 24
# Values:
# recurrence_class    no-recurrence-events
# age                                50-59
# menopause                        premeno
# tumor-size                         35-39
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              2
# breast                             right
# breast-quad                      left_up
# irradiat                              no
# Name: 24, dtype: object
#
# Index#: 25
# Values:
# recurrence_class    no-recurrence-events
# age                                40-49
# menopause                        premeno
# tumor-size                         25-29
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              2
# breast                              left
# breast-quad                      left_up
# irradiat                              no
# Name: 25, dtype: object
#
# Index#: 26
# Values:
# recurrence_class    no-recurrence-events
# age                                50-59
# menopause                        premeno
# tumor-size                         20-24
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              1
# breast                              left
# breast-quad                     left_low
# irradiat                              no
# Name: 26, dtype: object
#
# Index#: 27
# Values:
# recurrence_class    no-recurrence-events
# age                                60-69
# menopause                           ge40
# tumor-size                         25-29
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              3
# breast                             right
# breast-quad                      left_up
# irradiat                              no
# Name: 27, dtype: object
#
# Index#: 28
# Values:
# recurrence_class    no-recurrence-events
# age                                40-49
# menopause                        premeno
# tumor-size                         40-44
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              2
# breast                             right
# breast-quad                     left_low
# irradiat                              no
# Name: 28, dtype: object
#
# Index#: 29
# Values:
# recurrence_class    no-recurrence-events
# age                                60-69
# menopause                           ge40
# tumor-size                         30-34
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              2
# breast                              left
# breast-quad                     left_low
# irradiat                              no
# Name: 29, dtype: object
#
# Index#: 30
# Values:
# recurrence_class    no-recurrence-events
# age                                50-59
# menopause                           ge40
# tumor-size                         40-44
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              3
# breast                             right
# breast-quad                      left_up
# irradiat                              no
# Name: 30, dtype: object
#
# Index#: 31
# Values:
# recurrence_class    no-recurrence-events
# age                                50-59
# menopause                        premeno
# tumor-size                         15-19
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              2
# breast                             right
# breast-quad                     left_low
# irradiat                              no
# Name: 31, dtype: object
#
# Index#: 32
# Values:
# recurrence_class    no-recurrence-events
# age                                50-59
# menopause                        premeno
# tumor-size                         10-14
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              3
# breast                              left
# breast-quad                     left_low
# irradiat                              no
# Name: 32, dtype: object
#
# Index#: 33
# Values:
# recurrence_class    no-recurrence-events
# age                                50-59
# menopause                           ge40
# tumor-size                         10-14
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              1
# breast                             right
# breast-quad                      left_up
# irradiat                              no
# Name: 33, dtype: object
#
# Index#: 34
# Values:
# recurrence_class    no-recurrence-events
# age                                50-59
# menopause                           ge40
# tumor-size                         10-14
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              1
# breast                              left
# breast-quad                      left_up
# irradiat                              no
# Name: 34, dtype: object
#
# Index#: 35
# Values:
# recurrence_class    no-recurrence-events
# age                                30-39
# menopause                        premeno
# tumor-size                         30-34
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              2
# breast                              left
# breast-quad                      left_up
# irradiat                              no
# Name: 35, dtype: object
#
# Index#: 36
# Values:
# recurrence_class    no-recurrence-events
# age                                50-59
# menopause                           ge40
# tumor-size                           0-4
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              2
# breast                              left
# breast-quad                      central
# irradiat                              no
# Name: 36, dtype: object
#
# Index#: 37
# Values:
# recurrence_class    no-recurrence-events
# age                                50-59
# menopause                           ge40
# tumor-size                         15-19
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              1
# breast                             right
# breast-quad                      central
# irradiat                              no
# Name: 37, dtype: object
#
# Index#: 38
# Values:
# recurrence_class    no-recurrence-events
# age                                40-49
# menopause                        premeno
# tumor-size                         10-14
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              2
# breast                              left
# breast-quad                     left_low
# irradiat                              no
# Name: 38, dtype: object
#
# Index#: 39
# Values:
# recurrence_class    no-recurrence-events
# age                                40-49
# menopause                        premeno
# tumor-size                         30-34
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              1
# breast                              left
# breast-quad                     left_low
# irradiat                              no
# Name: 39, dtype: object
#
# Index#: 40
# Values:
# recurrence_class    no-recurrence-events
# age                                50-59
# menopause                           ge40
# tumor-size                         20-24
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              1
# breast                             right
# breast-quad                     left_low
# irradiat                              no
# Name: 40, dtype: object
#
# Index#: 41
# Values:
# recurrence_class    no-recurrence-events
# age                                60-69
# menopause                           ge40
# tumor-size                         25-29
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              2
# breast                              left
# breast-quad                     left_low
# irradiat                              no
# Name: 41, dtype: object
#
# Index#: 42
# Values:
# recurrence_class    no-recurrence-events
# age                                60-69
# menopause                           ge40
# tumor-size                           5-9
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              1
# breast                              left
# breast-quad                      central
# irradiat                              no
# Name: 42, dtype: object
#
# Index#: 43
# Values:
# recurrence_class    no-recurrence-events
# age                                40-49
# menopause                        premeno
# tumor-size                         10-14
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              2
# breast                              left
# breast-quad                      left_up
# irradiat                              no
# Name: 43, dtype: object
#
# Index#: 44
# Values:
# recurrence_class    no-recurrence-events
# age                                50-59
# menopause                           ge40
# tumor-size                         50-54
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              1
# breast                             right
# breast-quad                     right_up
# irradiat                              no
# Name: 44, dtype: object
#
# Index#: 45
# Values:
# recurrence_class    no-recurrence-events
# age                                50-59
# menopause                           ge40
# tumor-size                         30-34
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              1
# breast                              left
# breast-quad                      left_up
# irradiat                              no
# Name: 45, dtype: object
#
# Index#: 46
# Values:
# recurrence_class    no-recurrence-events
# age                                40-49
# menopause                        premeno
# tumor-size                         25-29
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              2
# breast                             right
# breast-quad                     left_low
# irradiat                              no
# Name: 46, dtype: object
#
# Index#: 47
# Values:
# recurrence_class    no-recurrence-events
# age                                50-59
# menopause                        premeno
# tumor-size                         25-29
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              1
# breast                             right
# breast-quad                      left_up
# irradiat                              no
# Name: 47, dtype: object
#
# Index#: 48
# Values:
# recurrence_class    no-recurrence-events
# age                                40-49
# menopause                        premeno
# tumor-size                         20-24
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              1
# breast                             right
# breast-quad                     right_up
# irradiat                              no
# Name: 48, dtype: object
#
# Index#: 49
# Values:
# recurrence_class    no-recurrence-events
# age                                40-49
# menopause                        premeno
# tumor-size                         20-24
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              1
# breast                             right
# breast-quad                     left_low
# irradiat                              no
# Name: 49, dtype: object
#
# Index#: 50
# Values:
# recurrence_class    no-recurrence-events
# age                                50-59
# menopause                           lt40
# tumor-size                         15-19
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              2
# breast                              left
# breast-quad                     left_low
# irradiat                              no
# Name: 50, dtype: object
#
# Index#: 51
# Values:
# recurrence_class    no-recurrence-events
# age                                30-39
# menopause                        premeno
# tumor-size                         20-24
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              2
# breast                              left
# breast-quad                    right_low
# irradiat                              no
# Name: 51, dtype: object
#
# Index#: 52
# Values:
# recurrence_class    no-recurrence-events
# age                                50-59
# menopause                        premeno
# tumor-size                         15-19
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              1
# breast                              left
# breast-quad                     left_low
# irradiat                              no
# Name: 52, dtype: object
#
# Index#: 53
# Values:
# recurrence_class    no-recurrence-events
# age                                70-79
# menopause                           ge40
# tumor-size                         20-24
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              3
# breast                              left
# breast-quad                      left_up
# irradiat                              no
# Name: 53, dtype: object
#
# Index#: 54
# Values:
# recurrence_class    no-recurrence-events
# age                                70-79
# menopause                           ge40
# tumor-size                         40-44
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              1
# breast                             right
# breast-quad                      left_up
# irradiat                              no
# Name: 54, dtype: object
#
# Index#: 55
# Values:
# recurrence_class    no-recurrence-events
# age                                70-79
# menopause                           ge40
# tumor-size                         40-44
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              1
# breast                             right
# breast-quad                     right_up
# irradiat                              no
# Name: 55, dtype: object
#
# Index#: 56
# Values:
# recurrence_class    no-recurrence-events
# age                                50-59
# menopause                           ge40
# tumor-size                           0-4
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              1
# breast                             right
# breast-quad                      central
# irradiat                              no
# Name: 56, dtype: object
#
# Index#: 57
# Values:
# recurrence_class    no-recurrence-events
# age                                50-59
# menopause                           ge40
# tumor-size                           5-9
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              2
# breast                             right
# breast-quad                     right_up
# irradiat                              no
# Name: 57, dtype: object
#
# Index#: 58
# Values:
# recurrence_class    no-recurrence-events
# age                                60-69
# menopause                           ge40
# tumor-size                         30-34
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              1
# breast                              left
# breast-quad                      left_up
# irradiat                              no
# Name: 58, dtype: object
#
# Index#: 59
# Values:
# recurrence_class    no-recurrence-events
# age                                60-69
# menopause                           ge40
# tumor-size                         15-19
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              1
# breast                             right
# breast-quad                      left_up
# irradiat                              no
# Name: 59, dtype: object
#
# Index#: 60
# Values:
# recurrence_class    no-recurrence-events
# age                                40-49
# menopause                        premeno
# tumor-size                         20-24
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              2
# breast                              left
# breast-quad                      central
# irradiat                              no
# Name: 60, dtype: object
#
# Index#: 61
# Values:
# recurrence_class    no-recurrence-events
# age                                40-49
# menopause                        premeno
# tumor-size                         10-14
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              1
# breast                             right
# breast-quad                    right_low
# irradiat                              no
# Name: 61, dtype: object
#
# Index#: 62
# Values:
# recurrence_class    no-recurrence-events
# age                                50-59
# menopause                           ge40
# tumor-size                           0-4
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              1
# breast                              left
# breast-quad                     left_low
# irradiat                              no
# Name: 62, dtype: object
#
# Index#: 63
# Values:
# recurrence_class    no-recurrence-events
# age                                20-29
# menopause                        premeno
# tumor-size                         35-39
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              2
# breast                             right
# breast-quad                     right_up
# irradiat                              no
# Name: 63, dtype: object
#
# Index#: 64
# Values:
# recurrence_class    no-recurrence-events
# age                                40-49
# menopause                        premeno
# tumor-size                         25-29
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              1
# breast                              left
# breast-quad                    right_low
# irradiat                              no
# Name: 64, dtype: object
#
# Index#: 65
# Values:
# recurrence_class    no-recurrence-events
# age                                40-49
# menopause                        premeno
# tumor-size                         10-14
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              1
# breast                             right
# breast-quad                      left_up
# irradiat                              no
# Name: 65, dtype: object
#
# Index#: 66
# Values:
# recurrence_class    no-recurrence-events
# age                                40-49
# menopause                        premeno
# tumor-size                         25-29
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              1
# breast                             right
# breast-quad                    right_low
# irradiat                              no
# Name: 66, dtype: object
#
# Index#: 67
# Values:
# recurrence_class    no-recurrence-events
# age                                50-59
# menopause                           ge40
# tumor-size                         20-24
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              3
# breast                              left
# breast-quad                      left_up
# irradiat                              no
# Name: 67, dtype: object
#
# Index#: 68
# Values:
# recurrence_class    no-recurrence-events
# age                                50-59
# menopause                           ge40
# tumor-size                         35-39
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              3
# breast                              left
# breast-quad                     left_low
# irradiat                              no
# Name: 68, dtype: object
#
# Index#: 69
# Values:
# recurrence_class    no-recurrence-events
# age                                60-69
# menopause                           ge40
# tumor-size                         50-54
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              2
# breast                              left
# breast-quad                     left_low
# irradiat                              no
# Name: 69, dtype: object
#
# Index#: 70
# Values:
# recurrence_class    no-recurrence-events
# age                                60-69
# menopause                           ge40
# tumor-size                         10-14
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              1
# breast                              left
# breast-quad                     left_low
# irradiat                              no
# Name: 70, dtype: object
#
# Index#: 71
# Values:
# recurrence_class    no-recurrence-events
# age                                40-49
# menopause                        premeno
# tumor-size                         25-29
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              2
# breast                             right
# breast-quad                      left_up
# irradiat                              no
# Name: 71, dtype: object
#
# Index#: 72
# Values:
# recurrence_class    no-recurrence-events
# age                                60-69
# menopause                           ge40
# tumor-size                         20-24
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              2
# breast                              left
# breast-quad                      left_up
# irradiat                              no
# Name: 72, dtype: object
#
# Index#: 73
# Values:
# recurrence_class    no-recurrence-events
# age                                50-59
# menopause                        premeno
# tumor-size                         15-19
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              2
# breast                             right
# breast-quad                    right_low
# irradiat                              no
# Name: 73, dtype: object
#
# Index#: 74
# Values:
# recurrence_class    no-recurrence-events
# age                                30-39
# menopause                        premeno
# tumor-size                           5-9
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              2
# breast                              left
# breast-quad                    right_low
# irradiat                              no
# Name: 74, dtype: object
#
# Index#: 75
# Values:
# recurrence_class    no-recurrence-events
# age                                50-59
# menopause                           ge40
# tumor-size                         10-14
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              1
# breast                              left
# breast-quad                     left_low
# irradiat                              no
# Name: 75, dtype: object
#
# Index#: 76
# Values:
# recurrence_class    no-recurrence-events
# age                                50-59
# menopause                           ge40
# tumor-size                         10-14
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              2
# breast                              left
# breast-quad                     left_low
# irradiat                              no
# Name: 76, dtype: object
#
# Index#: 77
# Values:
# recurrence_class    no-recurrence-events
# age                                30-39
# menopause                        premeno
# tumor-size                         25-29
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              1
# breast                              left
# breast-quad                      central
# irradiat                              no
# Name: 77, dtype: object
#
# Index#: 78
# Values:
# recurrence_class    no-recurrence-events
# age                                50-59
# menopause                        premeno
# tumor-size                         25-29
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              2
# breast                              left
# breast-quad                     left_low
# irradiat                              no
# Name: 78, dtype: object
#
# Index#: 79
# Values:
# recurrence_class    no-recurrence-events
# age                                40-49
# menopause                        premeno
# tumor-size                         25-29
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              2
# breast                             right
# breast-quad                      central
# irradiat                              no
# Name: 79, dtype: object
#
# Index#: 80
# Values:
# recurrence_class    no-recurrence-events
# age                                50-59
# menopause                           ge40
# tumor-size                         10-14
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              2
# breast                             right
# breast-quad                     left_low
# irradiat                              no
# Name: 80, dtype: object
#
# Index#: 81
# Values:
# recurrence_class    no-recurrence-events
# age                                60-69
# menopause                           ge40
# tumor-size                         10-14
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              1
# breast                              left
# breast-quad                      left_up
# irradiat                              no
# Name: 81, dtype: object
#
# Index#: 82
# Values:
# recurrence_class    no-recurrence-events
# age                                60-69
# menopause                           ge40
# tumor-size                         15-19
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              2
# breast                             right
# breast-quad                     left_low
# irradiat                              no
# Name: 82, dtype: object
#
# Index#: 83
# Values:
# recurrence_class    no-recurrence-events
# age                                50-59
# menopause                           ge40
# tumor-size                         15-19
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              2
# breast                             right
# breast-quad                     left_low
# irradiat                              no
# Name: 83, dtype: object
#
# Index#: 84
# Values:
# recurrence_class    no-recurrence-events
# age                                40-49
# menopause                        premeno
# tumor-size                         20-24
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              1
# breast                              left
# breast-quad                    right_low
# irradiat                              no
# Name: 84, dtype: object
#
# Index#: 85
# Values:
# recurrence_class    no-recurrence-events
# age                                50-59
# menopause                           ge40
# tumor-size                         35-39
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              3
# breast                              left
# breast-quad                      left_up
# irradiat                              no
# Name: 85, dtype: object
#
# Index#: 86
# Values:
# recurrence_class    no-recurrence-events
# age                                60-69
# menopause                           ge40
# tumor-size                         25-29
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              2
# breast                             right
# breast-quad                     left_low
# irradiat                              no
# Name: 86, dtype: object
#
# Index#: 87
# Values:
# recurrence_class    no-recurrence-events
# age                                70-79
# menopause                           ge40
# tumor-size                           0-4
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              1
# breast                              left
# breast-quad                    right_low
# irradiat                              no
# Name: 87, dtype: object
#
# Index#: 88
# Values:
# recurrence_class    no-recurrence-events
# age                                50-59
# menopause                           ge40
# tumor-size                         20-24
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              3
# breast                             right
# breast-quad                      left_up
# irradiat                              no
# Name: 88, dtype: object
#
# Index#: 89
# Values:
# recurrence_class    no-recurrence-events
# age                                40-49
# menopause                        premeno
# tumor-size                         40-44
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              1
# breast                             right
# breast-quad                      left_up
# irradiat                              no
# Name: 89, dtype: object
#
# Index#: 90
# Values:
# recurrence_class    no-recurrence-events
# age                                30-39
# menopause                        premeno
# tumor-size                           0-4
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              2
# breast                             right
# breast-quad                      central
# irradiat                              no
# Name: 90, dtype: object
#
# Index#: 91
# Values:
# recurrence_class    no-recurrence-events
# age                                50-59
# menopause                           ge40
# tumor-size                         20-24
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              3
# breast                              left
# breast-quad                      left_up
# irradiat                              no
# Name: 91, dtype: object
#
# Index#: 92
# Values:
# recurrence_class    no-recurrence-events
# age                                50-59
# menopause                           ge40
# tumor-size                         25-29
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              2
# breast                             right
# breast-quad                      left_up
# irradiat                              no
# Name: 92, dtype: object
#
# Index#: 93
# Values:
# recurrence_class    no-recurrence-events
# age                                60-69
# menopause                           ge40
# tumor-size                         20-24
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              2
# breast                             right
# breast-quad                      left_up
# irradiat                              no
# Name: 93, dtype: object
#
# Index#: 94
# Values:
# recurrence_class    no-recurrence-events
# age                                50-59
# menopause                        premeno
# tumor-size                         10-14
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              1
# breast                              left
# breast-quad                     left_low
# irradiat                              no
# Name: 94, dtype: object
#
# Index#: 95
# Values:
# recurrence_class    no-recurrence-events
# age                                40-49
# menopause                        premeno
# tumor-size                         30-34
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              2
# breast                             right
# breast-quad                    right_low
# irradiat                              no
# Name: 95, dtype: object
#
# Index#: 96
# Values:
# recurrence_class    no-recurrence-events
# age                                60-69
# menopause                           ge40
# tumor-size                         30-34
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              2
# breast                              left
# breast-quad                      left_up
# irradiat                              no
# Name: 96, dtype: object
#
# Index#: 97
# Values:
# recurrence_class    no-recurrence-events
# age                                60-69
# menopause                           ge40
# tumor-size                         15-19
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              2
# breast                             right
# breast-quad                      left_up
# irradiat                              no
# Name: 97, dtype: object
#
# Index#: 98
# Values:
# recurrence_class    no-recurrence-events
# age                                40-49
# menopause                        premeno
# tumor-size                         30-34
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              1
# breast                              left
# breast-quad                     right_up
# irradiat                              no
# Name: 98, dtype: object
#
# Index#: 99
# Values:
# recurrence_class    no-recurrence-events
# age                                30-39
# menopause                        premeno
# tumor-size                         25-29
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              2
# breast                              left
# breast-quad                     left_low
# irradiat                              no
# Name: 99, dtype: object
#
# Index#: 100
# Values:
# recurrence_class    no-recurrence-events
# age                                40-49
# menopause                           ge40
# tumor-size                         20-24
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              3
# breast                              left
# breast-quad                     left_low
# irradiat                              no
# Name: 100, dtype: object
#
# Index#: 101
# Values:
# recurrence_class    no-recurrence-events
# age                                50-59
# menopause                           ge40
# tumor-size                         30-34
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              3
# breast                             right
# breast-quad                     left_low
# irradiat                              no
# Name: 101, dtype: object
#
# Index#: 102
# Values:
# recurrence_class    no-recurrence-events
# age                                50-59
# menopause                        premeno
# tumor-size                         25-29
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              2
# breast                             right
# breast-quad                    right_low
# irradiat                              no
# Name: 102, dtype: object
#
# Index#: 103
# Values:
# recurrence_class    no-recurrence-events
# age                                40-49
# menopause                        premeno
# tumor-size                         20-24
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              2
# breast                              left
# breast-quad                    right_low
# irradiat                              no
# Name: 103, dtype: object
#
# Index#: 104
# Values:
# recurrence_class    no-recurrence-events
# age                                40-49
# menopause                        premeno
# tumor-size                         10-14
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              2
# breast                             right
# breast-quad                     left_low
# irradiat                              no
# Name: 104, dtype: object
#
# Index#: 105
# Values:
# recurrence_class    no-recurrence-events
# age                                40-49
# menopause                        premeno
# tumor-size                         30-34
# inv_nodes                            0-2
# node-caps                             no
# deg-malig                              1
# ...
# node-caps                         yes
# deg-malig                           3
# breast                           left
# breast-quad                  left_low
# irradiat                           no
# Name: 248, dtype: object
#
# Index#: 249
# Values:
# recurrence_class    recurrence-events
# age                             30-39
# menopause                     premeno
# tumor-size                      20-24
# inv_nodes                         3-5
# node-caps                         yes
# deg-malig                           2
# breast                           left
# breast-quad                  left_low
# irradiat                           no
# Name: 249, dtype: object
#
# Index#: 250
# Values:
# recurrence_class    recurrence-events
# age                             40-49
# menopause                     premeno
# tumor-size                      25-29
# inv_nodes                         0-2
# node-caps                          no
# deg-malig                           3
# breast                           left
# breast-quad                   left_up
# irradiat                           no
# Name: 250, dtype: object
#
# Index#: 251
# Values:
# recurrence_class    recurrence-events
# age                             40-49
# menopause                     premeno
# tumor-size                      50-54
# inv_nodes                         0-2
# node-caps                          no
# deg-malig                           2
# breast                          right
# breast-quad                  left_low
# irradiat                          yes
# Name: 251, dtype: object
#
# Index#: 252
# Values:
# recurrence_class    recurrence-events
# age                             30-39
# menopause                     premeno
# tumor-size                      40-44
# inv_nodes                         0-2
# node-caps                          no
# deg-malig                           1
# breast                           left
# breast-quad                   left_up
# irradiat                           no
# Name: 252, dtype: object
#
# Index#: 253
# Values:
# recurrence_class    recurrence-events
# age                             60-69
# menopause                        ge40
# tumor-size                      50-54
# inv_nodes                         0-2
# node-caps                          no
# deg-malig                           3
# breast                          right
# breast-quad                   left_up
# irradiat                           no
# Name: 253, dtype: object
#
# Index#: 254
# Values:
# recurrence_class    recurrence-events
# age                             40-49
# menopause                     premeno
# tumor-size                      30-34
# inv_nodes                         0-2
# node-caps                         yes
# deg-malig                           3
# breast                          right
# breast-quad                  right_up
# irradiat                           no
# Name: 254, dtype: object
#
# Index#: 255
# Values:
# recurrence_class    recurrence-events
# age                             40-49
# menopause                     premeno
# tumor-size                      30-34
# inv_nodes                         6-8
# node-caps                         yes
# deg-malig                           3
# breast                          right
# breast-quad                   left_up
# irradiat                           no
# Name: 255, dtype: object
#
# Index#: 256
# Values:
# recurrence_class    recurrence-events
# age                             40-49
# menopause                     premeno
# tumor-size                      30-34
# inv_nodes                         0-2
# node-caps                          no
# deg-malig                           1
# breast                           left
# breast-quad                  left_low
# irradiat                          yes
# Name: 256, dtype: object
#
# Index#: 257
# Values:
# recurrence_class    recurrence-events
# age                             40-49
# menopause                     premeno
# tumor-size                      20-24
# inv_nodes                         3-5
# node-caps                         yes
# deg-malig                           2
# breast                           left
# breast-quad                  left_low
# irradiat                          yes
# Name: 257, dtype: object
#
# Index#: 258
# Values:
# recurrence_class    recurrence-events
# age                             50-59
# menopause                        ge40
# tumor-size                      30-34
# inv_nodes                         6-8
# node-caps                         yes
# deg-malig                           2
# breast                           left
# breast-quad                 right_low
# irradiat                          yes
# Name: 258, dtype: object
#
# Index#: 259
# Values:
# recurrence_class    recurrence-events
# age                             50-59
# menopause                        ge40
# tumor-size                      30-34
# inv_nodes                         3-5
# node-caps                          no
# deg-malig                           3
# breast                          right
# breast-quad                   left_up
# irradiat                           no
# Name: 259, dtype: object
#
# Index#: 260
# Values:
# recurrence_class    recurrence-events
# age                             60-69
# menopause                        ge40
# tumor-size                      25-29
# inv_nodes                         3-5
# node-caps                          no
# deg-malig                           2
# breast                          right
# breast-quad                  right_up
# irradiat                           no
# Name: 260, dtype: object
#
# Index#: 261
# Values:
# recurrence_class    recurrence-events
# age                             40-49
# menopause                        ge40
# tumor-size                      25-29
# inv_nodes                       12-14
# node-caps                         yes
# deg-malig                           3
# breast                           left
# breast-quad                 right_low
# irradiat                          yes
# Name: 261, dtype: object
#
# Index#: 262
# Values:
# recurrence_class    recurrence-events
# age                             60-69
# menopause                        ge40
# tumor-size                      25-29
# inv_nodes                         0-2
# node-caps                          no
# deg-malig                           3
# breast                           left
# breast-quad                   left_up
# irradiat                           no
# Name: 262, dtype: object
#
# Index#: 263
# Values:
# recurrence_class    recurrence-events
# age                             50-59
# menopause                        lt40
# tumor-size                      20-24
# inv_nodes                         0-2
# node-caps                           ?
# deg-malig                           1
# breast                           left
# breast-quad                   left_up
# irradiat                           no
# Name: 263, dtype: object
#
# Index#: 264
# Values:
# recurrence_class    recurrence-events
# age                             50-59
# menopause                        lt40
# tumor-size                      20-24
# inv_nodes                         0-2
# node-caps                           ?
# deg-malig                           1
# breast                           left
# breast-quad                  left_low
# irradiat                           no
# Name: 264, dtype: object
#
# Index#: 265
# Values:
# recurrence_class    recurrence-events
# age                             30-39
# menopause                     premeno
# tumor-size                      35-39
# inv_nodes                        9-11
# node-caps                         yes
# deg-malig                           3
# breast                           left
# breast-quad                  left_low
# irradiat                           no
# Name: 265, dtype: object
#
# Index#: 266
# Values:
# recurrence_class    recurrence-events
# age                             40-49
# menopause                     premeno
# tumor-size                      30-34
# inv_nodes                         3-5
# node-caps                         yes
# deg-malig                           2
# breast                           left
# breast-quad                  right_up
# irradiat                           no
# Name: 266, dtype: object
#
# Index#: 267
# Values:
# recurrence_class    recurrence-events
# age                             60-69
# menopause                        ge40
# tumor-size                      20-24
# inv_nodes                       24-26
# node-caps                         yes
# deg-malig                           3
# breast                           left
# breast-quad                  left_low
# irradiat                          yes
# Name: 267, dtype: object
#
# Index#: 268
# Values:
# recurrence_class    recurrence-events
# age                             30-39
# menopause                     premeno
# tumor-size                      35-39
# inv_nodes                         0-2
# node-caps                          no
# deg-malig                           3
# breast                           left
# breast-quad                  left_low
# irradiat                           no
# Name: 268, dtype: object
#
# Index#: 269
# Values:
# recurrence_class    recurrence-events
# age                             40-49
# menopause                     premeno
# tumor-size                      25-29
# inv_nodes                         0-2
# node-caps                          no
# deg-malig                           2
# breast                           left
# breast-quad                  left_low
# irradiat                          yes
# Name: 269, dtype: object
#
# Index#: 270
# Values:
# recurrence_class    recurrence-events
# age                             50-59
# menopause                        ge40
# tumor-size                      30-34
# inv_nodes                         6-8
# node-caps                         yes
# deg-malig                           3
# breast                           left
# breast-quad                 right_low
# irradiat                           no
# Name: 270, dtype: object
#
# Index#: 271
# Values:
# recurrence_class    recurrence-events
# age                             50-59
# menopause                     premeno
# tumor-size                      25-29
# inv_nodes                         0-2
# node-caps                          no
# deg-malig                           3
# breast                          right
# breast-quad                  left_low
# irradiat                          yes
# Name: 271, dtype: object
#
# Index#: 272
# Values:
# recurrence_class    recurrence-events
# age                             40-49
# menopause                     premeno
# tumor-size                      15-19
# inv_nodes                         0-2
# node-caps                         yes
# deg-malig                           3
# breast                          right
# breast-quad                   left_up
# irradiat                           no
# Name: 272, dtype: object
#
# Index#: 273
# Values:
# recurrence_class    recurrence-events
# age                             60-69
# menopause                        ge40
# tumor-size                      30-34
# inv_nodes                         0-2
# node-caps                         yes
# deg-malig                           2
# breast                          right
# breast-quad                  right_up
# irradiat                          yes
# Name: 273, dtype: object
#
# Index#: 274
# Values:
# recurrence_class    recurrence-events
# age                             60-69
# menopause                        ge40
# tumor-size                      30-34
# inv_nodes                         3-5
# node-caps                         yes
# deg-malig                           2
# breast                           left
# breast-quad                   central
# irradiat                          yes
# Name: 274, dtype: object
#
# Index#: 275
# Values:
# recurrence_class    recurrence-events
# age                             40-49
# menopause                     premeno
# tumor-size                      25-29
# inv_nodes                        9-11
# node-caps                         yes
# deg-malig                           3
# breast                          right
# breast-quad                   left_up
# irradiat                           no
# Name: 275, dtype: object
#
# Index#: 276
# Values:
# recurrence_class    recurrence-events
# age                             30-39
# menopause                     premeno
# tumor-size                      25-29
# inv_nodes                         6-8
# node-caps                         yes
# deg-malig                           3
# breast                           left
# breast-quad                 right_low
# irradiat                          yes
# Name: 276, dtype: object
#
# Index#: 277
# Values:
# recurrence_class    recurrence-events
# age                             60-69
# menopause                        ge40
# tumor-size                      10-14
# inv_nodes                         6-8
# node-caps                         yes
# deg-malig                           3
# breast                           left
# breast-quad                   left_up
# irradiat                          yes
# Name: 277, dtype: object
#
# Index#: 278
# Values:
# recurrence_class    recurrence-events
# age                             50-59
# menopause                     premeno
# tumor-size                      35-39
# inv_nodes                       15-17
# node-caps                         yes
# deg-malig                           3
# breast                          right
# breast-quad                  right_up
# irradiat                           no
# Name: 278, dtype: object
#
# Index#: 279
# Values:
# recurrence_class    recurrence-events
# age                             50-59
# menopause                        ge40
# tumor-size                      40-44
# inv_nodes                         6-8
# node-caps                         yes
# deg-malig                           3
# breast                           left
# breast-quad                  left_low
# irradiat                          yes
# Name: 279, dtype: object
#
# Index#: 280
# Values:
# recurrence_class    recurrence-events
# age                             50-59
# menopause                        ge40
# tumor-size                      40-44
# inv_nodes                         6-8
# node-caps                         yes
# deg-malig                           3
# breast                           left
# breast-quad                  left_low
# irradiat                          yes
# Name: 280, dtype: object
#
# Index#: 281
# Values:
# recurrence_class    recurrence-events
# age                             30-39
# menopause                     premeno
# tumor-size                      30-34
# inv_nodes                         0-2
# node-caps                          no
# deg-malig                           2
# breast                           left
# breast-quad                   left_up
# irradiat                           no
# Name: 281, dtype: object
#
# Index#: 282
# Values:
# recurrence_class    recurrence-events
# age                             30-39
# menopause                     premeno
# tumor-size                      20-24
# inv_nodes                         0-2
# node-caps                          no
# deg-malig                           3
# breast                           left
# breast-quad                   left_up
# irradiat                          yes
# Name: 282, dtype: object
#
# Index#: 283
# Values:
# recurrence_class    recurrence-events
# age                             60-69
# menopause                        ge40
# tumor-size                      20-24
# inv_nodes                         0-2
# node-caps                          no
# deg-malig                           1
# breast                          right
# breast-quad                   left_up
# irradiat                           no
# Name: 283, dtype: object
#
# Index#: 284
# Values:
# recurrence_class    recurrence-events
# age                             40-49
# menopause                        ge40
# tumor-size                      30-34
# inv_nodes                         3-5
# node-caps                          no
# deg-malig                           3
# breast                           left
# breast-quad                  left_low
# irradiat                           no
# Name: 284, dtype: object
#
# Index#: 285
# Values:
# recurrence_class    recurrence-events
# age                             50-59
# menopause                        ge40
# tumor-size                      30-34
# inv_nodes                         3-5
# node-caps                          no
# deg-malig                           3
# breast                           left
# breast-quad                  left_low
# irradiat                           no
# Name: 285, dtype: object

# %% [markdown]
# ### Pivot
# degree of malignancy by tumor size and age

# %%
df.pivot_table(index='tumor-size', columns = 'age', values = 'deg-malig')
# Out:
# age         20-29     30-39     40-49     50-59     60-69  70-79
# tumor-size
# 0-4           NaN  2.000000  2.500000  1.333333       NaN    1.0
# 10-14         NaN  1.500000  1.625000  1.555556  1.500000    2.0
# 15-19         NaN  1.800000  2.600000  1.700000  1.888889    1.0
# 20-24         NaN  2.333333  2.047619  2.000000  1.875000    3.0
# 25-29         NaN  2.166667  2.111111  2.047619  2.222222    NaN
# 30-34         NaN  2.142857  2.200000  2.350000  2.076923    NaN
# 35-39         2.0  3.000000  2.000000  2.571429  3.000000    NaN
# 40-44         NaN  2.000000  1.800000  2.625000  2.333333    1.0
# 45-49         NaN       NaN  2.000000       NaN  2.000000    NaN
# 5-9           NaN  2.000000  1.000000  2.000000  1.000000    NaN
# 50-54         NaN       NaN  2.000000  1.666667  2.333333    NaN

# %% [markdown]
# ### Melt
# Explode the menopause and breast values using age as the index of the values

# %%
pd.melt(df, id_vars='age', value_vars=['menopause', 'breast'])
# Out:
#        age   variable    value
# 0    30-39  menopause  premeno
# 1    40-49  menopause  premeno
# 2    40-49  menopause  premeno
# 3    60-69  menopause     ge40
# 4    40-49  menopause  premeno
# ..     ...        ...      ...
# 567  30-39     breast     left
# 568  30-39     breast     left
# 569  60-69     breast    right
# 570  40-49     breast     left
# 571  50-59     breast     left
#
# [572 rows x 3 columns]
